# %%
import pandas as pd
data= pd.read_csv('heatmap.csv')

# %%
data1  =data.iloc[:, 1:6]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import seaborn as sborn
 
# Bigger than normal fonts
sborn.set(font_scale=1.5)
 
# Gigantic fonts
sborn.set(font_scale=2)

# %%
g = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
g.set_facecolor('xkcd:salmon')

# %%
fig = plt.figure(figsize=(15,15))
mask =np.zeros_like(data1.corr())
mask[np.triu_indices_from(mask)] = True
g = sns.heatmap(data1.corr(),annot=True, mask=mask, annot_kws={"size": 30},fmt='.2f',linewidths=.5,cmap='coolwarm')
g.set_facecolor('white')
plt.title('CORRELATION', fontsize=40)

plt.show()
fig.savefig('heatmap.png')

# %%
display heatmap
# Out:
#   File "<ipython-input-36-0d87b0cd5818>", line 1
#     display heatmap
#                   ^
# SyntaxError: invalid syntax
